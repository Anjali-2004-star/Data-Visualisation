# %% [markdown]
# <a href="https://colab.research.google.com/github/Anjali-2004-star/Data-Visualisation/blob/main/Salary_data_Data_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as st

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Salary_Dataset_with_Extra_Features.csv')
df
# Out:
#        Rating                      Company Name                 Job Title  \
# 0         3.8                            Sasken         Android Developer
# 1         4.5  Advanced Millennium Technologies         Android Developer
# 2         4.0                         Unacademy         Android Developer
# 3         3.8                SnapBizz Cloudtech         Android Developer
# 4         4.4            Appoids Tech Solutions         Android Developer
# ...       ...                               ...                       ...
# 22765     4.7                  Expert Solutions             Web Developer
# 22766     4.0           Nextgen Innovation Labs             Web Developer
# 22767     4.1                           Fresher  Full Stack Web Developer
# 22768     4.1                         Accenture  Full Stack Web Developer
# 22769     3.8                   Thomson Reuters   Associate Web Developer
#
#         Salary  Salaries Reported   Location Employment Status Job Roles
# ...

# %%
df.head()
# Out:
#    Rating                      Company Name          Job Title   Salary  \
# 0     3.8                            Sasken  Android Developer   400000
# 1     4.5  Advanced Millennium Technologies  Android Developer   400000
# 2     4.0                         Unacademy  Android Developer  1000000
# 3     3.8                SnapBizz Cloudtech  Android Developer   300000
# 4     4.4            Appoids Tech Solutions  Android Developer   600000
#
#    Salaries Reported   Location Employment Status Job Roles
# 0                  3  Bangalore         Full Time   Android
# 1                  3  Bangalore         Full Time   Android
# 2                  3  Bangalore         Full Time   Android
# 3                  3  Bangalore         Full Time   Android
# 4                  3  Bangalore         Full Time   Android

# %%
df.shape
# Out:
# (22770, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22770 entries, 0 to 22769
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Rating             22770 non-null  float64
#  1   Company Name       22770 non-null  object
#  2   Job Title          22770 non-null  object
#  3   Salary             22770 non-null  int64
#  4   Salaries Reported  22770 non-null  int64
#  5   Location           22770 non-null  object
#  6   Employment Status  22770 non-null  object
#  7   Job Roles          22770 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.4+ MB

# %%
df.describe()
# Out:
#              Rating        Salary  Salaries Reported
# count  22770.000000  2.277000e+04       22770.000000
# mean       3.918213  6.953872e+05           1.855775
# std        0.519675  8.843990e+05           6.823668
# min        1.000000  2.112000e+03           1.000000
# 25%        3.700000  3.000000e+05           1.000000
# 50%        3.900000  5.000000e+05           1.000000
# 75%        4.200000  9.000000e+05           1.000000
# max        5.000000  9.000000e+07         361.000000

# %%
df.describe(include = 'object')
# Out:
#                      Company Name                      Job Title   Location  \
# count                       22770                          22770      22770
# unique                      11261                           1080         10
# top     Tata Consultancy Services  Software Development Engineer  Bangalore
# freq                          271                           2351       8264
#
#        Employment Status Job Roles
# count              22770     22770
# unique                 4        11
# top            Full Time       SDE
# freq               20083      8183

# %%
df.columns
# Out:
# Index(['Rating', 'Company Name', 'Job Title', 'Salary', 'Salaries Reported',
#        'Location', 'Employment Status', 'Job Roles'],
#       dtype='object')

# %%
df['Job Title'].unique()[:20]
# Out:
# array(['Android Developer', 'Android Developer - Intern',
#        'Android Developer - Contractor', 'Android Developer Contractor',
#        'Senior Android Developer', 'Android Software Engineer',
#        'Android Engineer', 'Android Applications Developer - Intern',
#        'Android Applications Developer', 'Android App Developer - Intern',
#        'Senior Android Developer and Team Lead', 'Android Tech Lead',
#        'Product Engineer (Android)', 'Software Engineer - Android',
#        'Android Software Developer',
#        'Android Software Developer - Intern',
#        'Senior Android Developer Contractor',
#        'Junior Android Developer - Intern', 'Junior Android Developer',
#        'Android Applications Developer - Contractor'], dtype=object)

# %%
df['Job Roles'].unique()
# Out:
# array(['Android', 'Backend', 'Database', 'Frontend', 'IOS', 'Java',
#        'Mobile', 'SDE', 'Python', 'Web', 'Testing'], dtype=object)

# %%
df.isna().sum()
# Out:
# Rating               0
# Company Name         0
# Job Title            0
# Salary               0
# Salaries Reported    0
# Location             0
# Employment Status    0
# Job Roles            0
# dtype: int64

# %%
df['Rating'].value_counts()
# Out:
# 4.00    2895
# 3.90    2473
# 3.80    2471
# 4.10    2111
# 3.70    1479
# 4.20    1323
# 4.30    1294
# 3.60    1009
# 4.40     883
# 4.50     861
# 3.50     801
# 3.30     727
# 5.00     672
# 3.40     574
# 4.60     464
# 4.70     401
# 3.00     333
# 3.10     329
# 3.20     316
# 4.80     283
# 2.90     177
# 4.90     157
# 2.80     129
# 2.70      98
# 2.60      77
# 1.00      67
# 2.50      66
# 2.00      54
# 2.40      53
# 2.30      43
# 2.20      43
# 3.95      27
# 2.10      15
# 1.90      15
# 1.80      12
# 3.85      11
# 1.50       8
# 1.60       8
# 1.40       5
# 1.70       4
# 1.30       2
# Name: Rating, dtype: int64

# %%
def handlerating(value):
  value = round(value,1)
  return value
df['Rating'] = df['Rating'].apply(handlerating)

# %%
plt.figure(figsize=(10,5))
plt.title('Rating')
sns.countplot(df['Rating'])
plt.xlabel('Rating')
plt.ylabel('count')
plt.show()

# %%
top10_company_max_employees = df['Company Name'].value_counts()[:10]
top10_company_max_employees
# Out:
# Tata Consultancy Services         271
# Amazon                            184
# Infosys                           169
# Accenture                         150
# Cognizant Technology Solutions    144
# Wipro                             122
# IBM                               122
# HCL Technologies                  102
# Capgemini                         101
# Fresher                           101
# Name: Company Name, dtype: int64

# %%
plt.figure(figsize=(12,8))
plt.xticks(rotation = 90)
plt.title('Top 10 Company Max Employees')
plt.xlabel('Company Name')
plt.ylabel('Employees Size')
plt.bar(top10_company_max_employees.keys(),top10_company_max_employees)
# Out:
# <BarContainer object of 10 artists>

# %%
Top20_jobs = df['Job Title'].value_counts()[:20]
Top20_jobs
# Out:
# Software Development Engineer                   2351
# Android Developer                               2029
# Software Development Engineer (SDE)             1614
# Front End Developer                             1412
# Test Engineer                                   1314
# Web Developer                                    853
# Software Development Engineer - Intern           771
# Software Development Engineer In Test (SDET)     766
# Backend Developer                                534
# Python Developer                                 485
# IOS Developer                                    484
# Java Developer                                   387
# Senior IOS Developer                             351
# Senior Software Development Engineer             350
# Junior Java Developer                            330
# Senior Java Developer                            318
# Software Development Engineer I                  312
# Software Development Engineer (SDE) - Intern     297
# ...

# %%
plt.figure(figsize=(15,5))
plt.xticks(rotation = 90)
plt.title('Top 20 Jobs')
plt.xlabel('Job Name')
plt.ylabel('Number of Jobs')
plt.bar(Top20_jobs.keys(),Top20_jobs)
# Out:
# <BarContainer object of 20 artists>

# %%
df['Location'].value_counts()
# Out:
# Bangalore         8264
# Hyderabad         4467
# New Delhi         4176
# Chennai           2458
# Pune              2134
# Mumbai             749
# Kolkata            178
# Madhya Pradesh     155
# Kerala             108
# Jaipur              81
# Name: Location, dtype: int64

# %%
plt.figure(figsize = (15,10))
plt.title('Location of the most available Jobs')
plt.xlabel('Location')
plt.ylabel('Number of Jobs')
sns.countplot(data = df,x ='Location')
# Out:
# <Axes: title={'center': 'Location of the most available Jobs'}, xlabel='Location', ylabel='count'>

# %%
Employment_Status = df['Employment Status'].value_counts()
Employment_Status
# Out:
# Full Time     20083
# Intern         2106
# Contractor      548
# Trainee          33
# Name: Employment Status, dtype: int64

# %%
plt.figure(figsize = (10,5))
plt.pie(Employment_Status,labels = Employment_Status.keys(),autopct='%1.1f%%');

# %%
df['Job Roles'].value_counts()
# Out:
# SDE         8183
# Android     2945
# Frontend    2163
# Java        1858
# Testing     1740
# IOS         1631
# Backend     1194
# Web          999
# Python       947
# Database     865
# Mobile       245
# Name: Job Roles, dtype: int64

# %%
plt.figure(figsize = (9,4))
plt.title('Job Roles')
sns.countplot(data = df,x='Job Roles')
plt.xlabel('Job Roles')
plt.ylabel('No. of Jobs')
plt.show()

# %%
round(df.groupby('Job Roles')['Salary'].mean(),0)
# Out:
# Job Roles
# Android     565911.0
# Backend     748518.0
# Database    958584.0
# Frontend    610099.0
# IOS         695254.0
# Java        564710.0
# Mobile      882283.0
# Python      486023.0
# SDE         853795.0
# Testing     496298.0
# Web         415452.0
# Name: Salary, dtype: float64

# %%
plt.figure(figsize = (12,4))
plt.title('Average Salary Distribution for Job Roles')
plt.xlabel('Job Roles')
plt.ylabel('Salary')
sns.barplot(x='Job Roles',y= 'Salary',data = df)
# Out:
# <Axes: title={'center': 'Average Salary Distribution for Job Roles'}, xlabel='Job Roles', ylabel='Salary'>

# %%
round(df.groupby('Location')['Salary'].mean(),0)
# Out:
# Location
# Bangalore         735345.0
# Chennai           584560.0
# Hyderabad         679099.0
# Jaipur            629136.0
# Kerala            553577.0
# Kolkata           710926.0
# Madhya Pradesh    677642.0
# Mumbai            961180.0
# New Delhi         658757.0
# Pune              690476.0
# Name: Salary, dtype: float64

# %%
plt.figure(figsize=(15,5))
plt.title('Average Salary Distribution for Location')
sns.barplot(x='Location',y='Salary',data=df);

# %%
df.groupby('Location')['Employment Status'].value_counts()
# Out:
# Location        Employment Status
# Bangalore       Full Time            7210
#                 Intern                798
#                 Contractor            248
#                 Trainee                 8
# Chennai         Full Time            2255
#                 Intern                151
#                 Contractor             41
#                 Trainee                11
# Hyderabad       Full Time            4070
#                 Intern                249
#                 Contractor            142
#                 Trainee                 6
# Jaipur          Full Time              68
#                 Intern                 13
# Kerala          Full Time             101
#                 Intern                  6
#                 Contractor              1
# Kolkata         Full Time             141
#                 Intern                 35
#                 Contractor              1
#                 Trainee                 1
# ...

# %%
plt.figure(figsize=(20,5))
sns.countplot(data = df,x= 'Location',hue='Employment Status');

# %%
df.groupby('Job Roles')['Location'].value_counts()
# Out:
# Job Roles  Location
# Android    New Delhi          980
#            Bangalore          940
#            Pune               381
#            Hyderabad          336
#            Chennai            308
# Backend    Bangalore          479
#            New Delhi          399
#            Hyderabad          112
#            Pune               105
#            Chennai             98
#            Mumbai               1
# Database   Bangalore          864
#            Chennai              1
# Frontend   Bangalore          826
#            New Delhi          380
#            Pune               327
#            Hyderabad          323
#            Chennai            307
# IOS        New Delhi          721
#            Bangalore          482
#            Pune               247
#            Hyderabad          180
#            Mumbai               1
# Java       Hyderabad          962
#            Chennai            896
# Mobile     Bangalore          245
# Python     Bangalore          467
# ...

# %%
plt.figure(figsize=(25,5))
sns.countplot(data=df,x= 'Job Roles',hue='Location');

# %%
df.groupby('Job Roles')['Employment Status'].value_counts()
# Out:
# Job Roles  Employment Status
# Android    Full Time            2669
#            Intern                225
#            Contractor             42
#            Trainee                 9
# Backend    Full Time             993
#            Intern                193
#            Contractor              8
# Database   Full Time             803
#            Contractor             56
#            Intern                  6
# Frontend   Full Time            1938
#            Intern                192
#            Contractor             33
# IOS        Full Time            1561
#            Intern                 47
#            Contractor             22
#            Trainee                 1
# Java       Full Time            1740
#            Contractor             60
#            Intern                 51
#            Trainee                 7
# Mobile     Full Time             229
#            Intern                 11
#            Contractor              4
# ...

# %%
plt.figure(figsize=(25,5))
sns.countplot(data=df,x= 'Job Roles',hue='Employment Status');

# %%
plt.figure(figsize=(20,10))
sns.barplot(x='Location',y='Salary',hue='Employment Status',data=df);

# %%
plt.figure(figsize = (20, 6))
plt.xticks(rotation = 90)
plt.ticklabel_format(style = 'plain')
df.sort_values("Salary", axis = 0, ascending = False, inplace = True)
sns.barplot(x = df["Company Name"][1:41],
 y = df["Salary"][1:41],
 palette = "spring");

# %%
# Top 20 Companies with 5.0 Rating
df[['Company Name','Rating']].sort_values(by='Rating',ascending=False).head(20)
# Out:
#                        Company Name  Rating
# 252                           GetVu     5.0
# 7014                     Vistaar360     5.0
# 6120     Jorim Technology Solutions     5.0
# 2238                Digitally Xpert     5.0
# 12575          Vivikta Technologies     5.0
# 17305                      LaborHub     5.0
# 5994                          adyog     5.0
# 8633             Tecocraft Infusion     5.0
# 11550               Arann Cyber tec     5.0
# 5644                  Golden Unicon     5.0
# 2866              Vrishank Softtech     5.0
# 15369                       Centime     5.0
# 8955               SGM Technologies     5.0
# 21142  Anyonyam Consulting Services     5.0
# 4131                     McCoy Mart     5.0
# 11092                       crossml     5.0
# 10187                   Axiom xCell     5.0
# 16922                        SSTech     5.0
# 20301              Ongo Recruitment     5.0
# 20195                       Nektrix     5.0

# %%
# Top 10 Highest Salary Jobs
df.nlargest(10,['Salary'])
# Out:
#        Rating            Company Name  \
# 18635     3.6       Thapar University
# 9260      3.6       OASYS Cybernetics
# 4471      3.8              Concentrix
# 7121      3.5          Koru UX Design
# 5819      3.7          Nityo Infotech
# 16062     3.8                  Amazon
# 18654     4.3            Digital Raju
# 16619     4.2         FFF Enterprises
# 15568     5.0  Gaana Lyrics Point.com
# 10832     4.6    GGH Heavy Industries
#
#                                            Job Title    Salary  \
# 18635            Software Development Engineer (SDE)  90000000
# 9260                           Senior Java Developer  10000000
# 4471                   Oracle Database Administrator  10000000
# 7121                      Senior Front End Developer  10000000
# 5819   Lead UI Designer, Magento Front-end Developer   9900000
# 16062            Software Development Engineer (SDE)   9850000
# 18654            Software Development Engineer (SDE)   9800000
# ...

# %%
df.nsmallest(10,['Salary'])
# Out:
#        Rating                 Company Name  \
# 22563     2.6          Keeves Technologies
# 9937      3.7                      Virtusa
# 5463      4.1                     Scholify
# 14659     4.4                    Microsoft
# 5548      4.0  Nasya Software Technologies
# 7514      3.9                   Al-Jazirah
# 22028     3.9                     Yes Bank
# 2472      3.5        Acmatics Technologies
# 18429     4.0                         ....
# 16838     4.4   Excel Engineering Services
#
#                                   Job Title  Salary  Salaries Reported  \
# 22563                Web Developer - Intern    2112                  1
# 9937                  Junior Java Developer    8448                  5
# 5463           Front End Developer - Intern   12000                  1
# 14659         Software Development Engineer   12000                  1
# 5548           Front End Developer - Intern   12000                  1
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
observation_table = pd.crosstab(df['Employment Status'],df['Job Roles'])

chi_value, p_value, degree_of_freedom, expectation_table = st.chi2_contingency(observation_table)

alpha = 0.05
if p_value<alpha:
    print("There is no relation between job roles and employment status")
else:
    print("There is relation between job roles and employment status")
# Out:
# There is no relation between job roles and employment status
